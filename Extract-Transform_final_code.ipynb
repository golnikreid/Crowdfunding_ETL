# %%
import pandas as pd
import json

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 1: Use Python Dictionary Methods
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Iterate through the DataFrame and convert each row to a dictionary.
# 3. Iterate through each dictionary and do the following:
#     * Extract the dictionary values from the keys using Python list comprehension.
#     * Add the values for each row to a new list.
# 4. Create a new DataFrame with the retrieved data.
# 5. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
backers_df = pd.read_csv("backer_info.csv")
backers_df.head()
backers_df.to_dict()["backer_info"]
# Out:
# {0: '{"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}',
#  1: '{"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}',
#  2: '{"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}',
#  3: '{"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}',
#  4: '{"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}',
#  5: '{"backer_id": "lh382", "cf_id": 563, "name": "Lambert Huber", "email": "lhuber@live.com"}',
#  6: '{"backer_id": "em444", "cf_id": 563, "name": "Emmy Morin", "email": "emorin@live.com"}',
#  7: '{"backer_id": "at582", "cf_id": 1572, "name": "Armonda Trani", "email": "atrani@live.com"}',
#  8: '{"backer_id": "id772", "cf_id": 1911, "name": "Ilana Duke", "email": "iduke@outlook.com"}',
#  9: '{"backer_id": "lw275", "cf_id": 65, "name": "Leigha Wright", "email": "lwright@live.com"}',
#  10: '{"backer_id": "ub509", "cf_id": 65, "name": "Uwe Becker", "email": "ubecker@yahoo.com"}',
#  11: '{"backer_id": "ha915", "cf_id": 1572, "name": "Hawa Audy", "email": "haudy@gmail.com"}',
#  12: '{"backer_id": "bb881", "cf_id": 968, "name": "Bia Bonura", "email": "bbonura@yahoo.com"}',
#  13: '{"backer_id": "mg332", "cf_id": 65, "name": "Michel Garner", "email": "mgarner@protonmail.com"}',
#  14: '{"backer_id": "kd700", "cf_id": 1572, "name": "Karole Dunn", "email": "kdunn@yahoo.com"}',
#  15: '{"backer_id": "as695", "cf_id": 563, "name": "Arndt Schreiber", "email": "aschreiber@yahoo.com"}',
#  16: '{"backer_id": "iv513", "cf_id": 65, "name": "Imen Villeneuve", "email": "ivilleneuve@yahoo.com"}',
#  17: '{"backer_id": "ab842", "cf_id": 65, "name": "Alcina Bonadonna", "email": "abonadonna@yandex.com"}',
#  18: '{"backer_id": "re181", "cf_id": 1114, "name": "Raelene Espinoza", "email": "respinoza@outlook.com"}',
#  19: '{"backer_id": "kn133", "cf_id": 65, "name": "Kati Nash", "email": "knash@protonmail.com"}',
#  20: '{"backer_id": "gj893", "cf_id": 65, "name": "Georg Jager", "email": "gjager@yahoo.com"}',
#  21: '{"backer_id": "vp915", "cf_id": 948, "name": "Virgilio Paolella", "email": "vpaolella@gmail.com"}',
#  22: '{"backer_id": "ja995", "cf_id": 563, "name": "Jerrica Avila", "email": "javila@protonmail.com"}',
#  23: '{"backer_id": "ga249", "cf_id": 563, "name": "Gianni Achterberg", "email": "gachterberg@live.com"}',
#  24: '{"backer_id": "td403", "cf_id": 65, "name": "Timoteo Dion", "email": "tdion@gmail.com"}',
#  25: '{"backer_id": "tv463", "cf_id": 1572, "name": "Teodoro Verno", "email": "tverno@yandex.com"}',
#  26: '{"backer_id": "mw606", "cf_id": 65, "name": "Morris Waller", "email": "mwaller@protonmail.com"}',
#  27: '{"backer_id": "hc648", "cf_id": 65, "name": "Hans Chen", "email": "hchen@yandex.com"}',
#  28: '{"backer_id": "ta379", "cf_id": 563, "name": "Trilby Auer", "email": "tauer@yahoo.com"}',
#  29: '{"backer_id": "tj583", "cf_id": 1572, "name": "Theola Jodoin", "email": "tjodoin@yandex.com"}',
#  30: '{"backer_id": "tc559", "cf_id": 65, "name": "Tova Capri", "email": "tcapri@live.com"}',
#  31: '{"backer_id": "ww629", "cf_id": 65, "name": "Wanda Walton", "email": "wwalton@protonmail.com"}',
#  32: '{"backer_id": "jg155", "cf_id": 1572, "name": "Justine Gill", "email": "jgill@yahoo.com"}',
#  33: '{"backer_id": "jd328", "cf_id": 1911, "name": "Julee Doyle", "email": "jdoyle@gmail.com"}',
#  34: '{"backer_id": "ld239", "cf_id": 65, "name": "Lisbeth Deliso", "email": "ldeliso@gmail.com"}',
#  35: '{"backer_id": "cv918", "cf_id": 968, "name": "Carl Valdez", "email": "cvaldez@gmail.com"}',
#  36: '{"backer_id": "kb145", "cf_id": 563, "name": "Kelyan Butler", "email": "kbutler@yahoo.com"}',
#  37: '{"backer_id": "dw578", "cf_id": 65, "name": "Donat Weber", "email": "dweber@live.com"}',
#  38: '{"backer_id": "ad511", "cf_id": 65, "name": "Alethia Delorme", "email": "adelorme@outlook.com"}',
#  39: '{"backer_id": "db633", "cf_id": 65, "name": "Darrell Bernardi", "email": "dbernardi@yandex.com"}',
#  40: '{"backer_id": "cr369", "cf_id": 65, "name": "Carina Reeves", "email": "creeves@gmail.com"}',
#  41: '{"backer_id": "mr978", "cf_id": 65, "name": "Marvin Ruiz", "email": "mruiz@outlook.com"}',
#  42: '{"backer_id": "md167", "cf_id": 1572, "name": "Mariabella Duerr", "email": "mduerr@live.com"}',
#  43: '{"backer_id": "jr877", "cf_id": 1572, "name": "Jeni Ricco", "email": "jricco@live.com"}',
#  44: '{"backer_id": "om753", "cf_id": 65, "name": "Otto Munoz", "email": "omunoz@yahoo.com"}',
#  45: '{"backer_id": "ng231", "cf_id": 1114, "name": "Nesrine Gensch", "email": "ngensch@yandex.com"}',
#  46: '{"backer_id": "tl316", "cf_id": 65, "name": "Tullio Lejeune", "email": "tlejeune@outlook.com"}',
#  47: '{"backer_id": "dl139", "cf_id": 563, "name": "Dreama Lonardo", "email": "dlonardo@live.com"}',
#  48: '{"backer_id": "mw253", "cf_id": 968, "name": "Maryrose West", "email": "mwest@live.com"}',
#  49: '{"backer_id": "im424", "cf_id": 65, "name": "Irina Mays", "email": "imays@yandex.com"}',
#  50: '{"backer_id": "mb131", "cf_id": 968, "name": "Marcelo Brose", "email": "mbrose@protonmail.com"}',
#  51: '{"backer_id": "nc240", "cf_id": 1572, "name": "Nestor Coutant", "email": "ncoutant@gmail.com"}',
#  52: '{"backer_id": "ab318", "cf_id": 1572, "name": "Aloysius Braun", "email": "abraun@live.com"}',
#  53: '{"backer_id": "af301", "cf_id": 65, "name": "Amos Ferre", "email": "aferre@gmail.com"}',
#  54: '{"backer_id": "bl736", "cf_id": 563, "name": "Brigitte Lynch", "email": "blynch@outlook.com"}',
#  55: '{"backer_id": "ar957", "cf_id": 65, "name": "Alegra Ramsey", "email": "aramsey@yahoo.com"}',
#  56: '{"backer_id": "cb474", "cf_id": 968, "name": "Conchita Beitel", "email": "cbeitel@gmail.com"}',
#  57: '{"backer_id": "dv246", "cf_id": 1572, "name": "Donnie Vernet", "email": "dvernet@protonmail.com"}',
#  58: '{"backer_id": "cj111", "cf_id": 563, "name": "Cyril Jones", "email": "cjones@protonmail.com"}',
#  59: '{"backer_id": "lh765", "cf_id": 563, "name": "Lucinda Hays", "email": "lhays@outlook.com"}',
#  60: '{"backer_id": "wh697", "cf_id": 65, "name": "Walter Hermann", "email": "whermann@outlook.com"}',
#  61: '{"backer_id": "eb714", "cf_id": 65, "name": "Emil Blanc", "email": "eblanc@protonmail.com"}',
#  62: '{"backer_id": "ec356", "cf_id": 1572, "name": "Eldwin Cesare", "email": "ecesare@protonmail.com"}',
#  63: '{"backer_id": "yh129", "cf_id": 65, "name": "Yusuf Hudson", "email": "yhudson@protonmail.com"}',
#  64: '{"backer_id": "as494", "cf_id": 65, "name": "Arrigo Salazar", "email": "asalazar@gmail.com"}',
#  65: '{"backer_id": "lb146", "cf_id": 563, "name": "Levi Beck", "email": "lbeck@gmail.com"}',
#  66: '{"backer_id": "cc470", "cf_id": 563, "name": "Celinda Caillet", "email": "ccaillet@yandex.com"}',
#  67: '{"backer_id": "mm239", "cf_id": 563, "name": "Marcus Medici", "email": "mmedici@gmail.com"}',
#  68: '{"backer_id": "dg360", "cf_id": 65, "name": "Daysi Gamble", "email": "dgamble@yahoo.com"}',
#  69: '{"backer_id": "rh399", "cf_id": 1572, "name": "Rory Hildebrand", "email": "rhildebrand@yahoo.com"}',
#  70: '{"backer_id": "hr430", "cf_id": 65, "name": "Heini Raffin", "email": "hraffin@yahoo.com"}',
#  71: '{"backer_id": "ar829", "cf_id": 65, "name": "Anna Randall", "email": "arandall@outlook.com"}',
#  72: '{"backer_id": "sw301", "cf_id": 65, "name": "Sharmaine Weber", "email": "sweber@yahoo.com"}',
#  73: '{"backer_id": "rr355", "cf_id": 65, "name": "Ranee Renault", "email": "rrenault@outlook.com"}',
#  74: '{"backer_id": "zc515", "cf_id": 1572, "name": "Zak Cianciola", "email": "zcianciola@yahoo.com"}',
#  75: '{"backer_id": "gp101", "cf_id": 65, "name": "Granville Potts", "email": "gpotts@gmail.com"}',
#  76: '{"backer_id": "bm741", "cf_id": 65, "name": "Bo Marsh", "email": "bmarsh@live.com"}',
#  77: '{"backer_id": "jd148", "cf_id": 65, "name": "Jay Duerr", "email": "jduerr@yahoo.com"}',
#  78: '{"backer_id": "mm632", "cf_id": 65, "name": "Milla Morin", "email": "mmorin@yahoo.com"}',
#  79: '{"backer_id": "ls884", "cf_id": 65, "name": "Leanne Savage", "email": "lsavage@gmail.com"}',
#  80: '{"backer_id": "sp364", "cf_id": 968, "name": "Silvana Patton", "email": "spatton@live.com"}',
#  81: '{"backer_id": "hh963", "cf_id": 65, "name": "Harvey Hoch", "email": "hhoch@outlook.com"}',
#  82: '{"backer_id": "sb272", "cf_id": 65, "name": "Seth Berthier", "email": "sberthier@protonmail.com"}',
#  83: '{"backer_id": "et566", "cf_id": 1114, "name": "Eugen Trani", "email": "etrani@protonmail.com"}',
#  84: '{"backer_id": "sd421", "cf_id": 1572, "name": "Santina Dieter", "email": "sdieter@yahoo.com"}',
#  85: '{"backer_id": "tg563", "cf_id": 65, "name": "Trinh Gregoire", "email": "tgregoire@live.com"}',
#  86: '{"backer_id": "kc571", "cf_id": 968, "name": "Karin Celano", "email": "kcelano@yandex.com"}',
#  87: '{"backer_id": "sd121", "cf_id": 1114, "name": "Sofia Decker", "email": "sdecker@yahoo.com"}',
#  88: '{"backer_id": "sk744", "cf_id": 65, "name": "Sherise Keller", "email": "skeller@outlook.com"}',
#  89: '{"backer_id": "km642", "cf_id": 65, "name": "Kirby Michel", "email": "kmichel@gmail.com"}',
#  90: '{"backer_id": "fu320", "cf_id": 65, "name": "Florentine Ungaro", "email": "fungaro@yandex.com"}',
#  91: '{"backer_id": "ld180", "cf_id": 1911, "name": "Louise Dejesus", "email": "ldejesus@yandex.com"}',
#  92: '{"backer_id": "ds377", "cf_id": 65, "name": "Daniele Suarez", "email": "dsuarez@yahoo.com"}',
#  93: '{"backer_id": "bb692", "cf_id": 65, "name": "Beckie Buchholz", "email": "bbuchholz@live.com"}',
#  94: '{"backer_id": "wd557", "cf_id": 563, "name": "William Dickson", "email": "wdickson@yandex.com"}',
#  95: '{"backer_id": "jd905", "cf_id": 65, "name": "Jolie Daugherty", "email": "jdaugherty@gmail.com"}',
#  96: '{"backer_id": "dd770", "cf_id": 65, "name": "Detta Dressler", "email": "ddressler@yahoo.com"}',
#  97: '{"backer_id": "cv698", "cf_id": 238, "name": "Clifton Villette", "email": "cvillette@outlook.com"}',
#  98: '{"backer_id": "cn307", "cf_id": 968, "name": "Cythia Netti", "email": "cnetti@outlook.com"}',
#  99: '{"backer_id": "eb198", "cf_id": 1572, "name": "Elsbeth Butler", "email": "ebutler@yahoo.com"}',
#  100: '{"backer_id": "am869", "cf_id": 65, "name": "Ambrine Mann", "email": "amann@yahoo.com"}',
#  101: '{"backer_id": "gr400", "cf_id": 1911, "name": "Gerald Robert", "email": "grobert@protonmail.com"}',
#  102: '{"backer_id": "az657", "cf_id": 563, "name": "Assunta Zezza", "email": "azezza@live.com"}',
#  103: '{"backer_id": "kc598", "cf_id": 1572, "name": "Kerstin Campbell", "email": "kcampbell@protonmail.com"}',
#  104: '{"backer_id": "lb588", "cf_id": 65, "name": "Lino Brock", "email": "lbrock@outlook.com"}',
#  105: '{"backer_id": "rl866", "cf_id": 65, "name": "Rubie Levasseur", "email": "rlevasseur@gmail.com"}',
#  106: '{"backer_id": "jf340", "cf_id": 65, "name": "Johann Flowers", "email": "jflowers@live.com"}',
#  107: '{"backer_id": "tb384", "cf_id": 1572, "name": "Thibaud Bullock", "email": "tbullock@yahoo.com"}',
#  108: '{"backer_id": "dg290", "cf_id": 65, "name": "Dan Gallois", "email": "dgallois@outlook.com"}',
#  109: '{"backer_id": "rr518", "cf_id": 65, "name": "Rolf Richards", "email": "rrichards@live.com"}',
#  110: '{"backer_id": "sh779", "cf_id": 968, "name": "Selyan Hoffman", "email": "shoffman@outlook.com"}',
#  111: '{"backer_id": "lw525", "cf_id": 65, "name": "Lucca Weber", "email": "lweber@live.com"}',
#  112: '{"backer_id": "sl474", "cf_id": 563, "name": "Sydney Louvet", "email": "slouvet@gmail.com"}',
#  113: '{"backer_id": "dp154", "cf_id": 65, "name": "Dusty Paola", "email": "dpaola@outlook.com"}',
#  114: '{"backer_id": "id770", "cf_id": 238, "name": "Ilario Dressler", "email": "idressler@protonmail.com"}',
#  115: '{"backer_id": "ek669", "cf_id": 65, "name": "Emile Khan", "email": "ekhan@outlook.com"}',
#  116: '{"backer_id": "eb945", "cf_id": 65, "name": "Elliot Bonomo", "email": "ebonomo@yandex.com"}',
#  117: '{"backer_id": "ag917", "cf_id": 1114, "name": "Arvin Golden", "email": "agolden@yandex.com"}',
#  118: '{"backer_id": "ac437", "cf_id": 563, "name": "Ampelio Cabrera", "email": "acabrera@live.com"}',
#  119: '{"backer_id": "sf583", "cf_id": 1572, "name": "Somer Fuhrmann", "email": "sfuhrmann@yahoo.com"}',
#  120: '{"backer_id": "sa973", "cf_id": 65, "name": "Shanti Allard", "email": "sallard@yandex.com"}',
#  121: '{"backer_id": "kc836", "cf_id": 65, "name": "Konstanze Caroselli", "email": "kcaroselli@yandex.com"}',
#  122: '{"backer_id": "bt844", "cf_id": 65, "name": "Bellarmine Taylor", "email": "btaylor@outlook.com"}',
#  123: '{"backer_id": "mf392", "cf_id": 65, "name": "Matthew Fischer", "email": "mfischer@live.com"}',
#  124: '{"backer_id": "dh568", "cf_id": 65, "name": "Dan Hoffmann", "email": "dhoffmann@yandex.com"}',
#  125: '{"backer_id": "iv880", "cf_id": 968, "name": "Imelda Vallee", "email": "ivallee@gmail.com"}',
#  126: '{"backer_id": "gl219", "cf_id": 1572, "name": "Giancarlo Lindsey", "email": "glindsey@protonmail.com"}',
#  127: '{"backer_id": "kb890", "cf_id": 1572, "name": "Kris Brennan", "email": "kbrennan@protonmail.com"}',
#  128: '{"backer_id": "jf901", "cf_id": 65, "name": "Johnnie Fux", "email": "jfux@gmail.com"}',
#  129: '{"backer_id": "ja340", "cf_id": 1114, "name": "Janeth Adam", "email": "jadam@protonmail.com"}',
#  130: '{"backer_id": "ar906", "cf_id": 65, "name": "Agata Rosa", "email": "arosa@yahoo.com"}',
#  131: '{"backer_id": "dc579", "cf_id": 65, "name": "Dennise Cabrera", "email": "dcabrera@live.com"}',
#  132: '{"backer_id": "gg660", "cf_id": 65, "name": "Garret Geier", "email": "ggeier@yahoo.com"}',
#  133: '{"backer_id": "db112", "cf_id": 65, "name": "Delia Beguin", "email": "dbeguin@yandex.com"}',
#  134: '{"backer_id": "ld487", "cf_id": 65, "name": "Louanne Damiani", "email": "ldamiani@outlook.com"}',
#  135: '{"backer_id": "bj475", "cf_id": 1572, "name": "Bronze Jenkins", "email": "bjenkins@protonmail.com"}',
#  136: '{"backer_id": "mc838", "cf_id": 65, "name": "Mila Coffey", "email": "mcoffey@protonmail.com"}',
#  137: '{"backer_id": "he768", "cf_id": 65, "name": "Hank Essert", "email": "hessert@gmail.com"}',
#  138: '{"backer_id": "pm973", "cf_id": 65, "name": "Paulina Marais", "email": "pmarais@protonmail.com"}',
#  139: '{"backer_id": "bf986", "cf_id": 65, "name": "Beatrice Fulco", "email": "bfulco@gmail.com"}',
#  140: '{"backer_id": "sb322", "cf_id": 65, "name": "Sudie Burgess", "email": "sburgess@yandex.com"}',
#  141: '{"backer_id": "ps571", "cf_id": 563, "name": "Prince Suarez", "email": "psuarez@yahoo.com"}',
#  142: '{"backer_id": "mb333", "cf_id": 1572, "name": "Mitzi Biermann", "email": "mbiermann@gmail.com"}',
#  143: '{"backer_id": "ab290", "cf_id": 1572, "name": "Aminata Bru", "email": "abru@yahoo.com"}',
#  144: '{"backer_id": "jm190", "cf_id": 968, "name": "Jina Magrino", "email": "jmagrino@live.com"}',
#  145: '{"backer_id": "rg933", "cf_id": 65, "name": "Rosena Gould", "email": "rgould@gmail.com"}',
#  146: '{"backer_id": "ik787", "cf_id": 1572, "name": "Issac Kline", "email": "ikline@live.com"}',
#  147: '{"backer_id": "rl982", "cf_id": 65, "name": "Roderica Lehmann", "email": "rlehmann@gmail.com"}',
#  148: '{"backer_id": "ac179", "cf_id": 65, "name": "Ariah Comte", "email": "acomte@yandex.com"}',
#  149: '{"backer_id": "eg193", "cf_id": 238, "name": "Ellis Gamble", "email": "egamble@yahoo.com"}',
#  150: '{"backer_id": "fl258", "cf_id": 65, "name": "Friedrich Lott", "email": "flott@yandex.com"}',
#  151: '{"backer_id": "mb203", "cf_id": 1114, "name": "Marilou Beutel", "email": "mbeutel@gmail.com"}',
#  152: '{"backer_id": "en399", "cf_id": 65, "name": "Elene Navarro", "email": "enavarro@yahoo.com"}',
#  153: '{"backer_id": "mr756", "cf_id": 968, "name": "Mac Raffin", "email": "mraffin@yahoo.com"}',
#  154: '{"backer_id": "sc271", "cf_id": 563, "name": "Shona Carr", "email": "scarr@outlook.com"}',
#  155: '{"backer_id": "xg684", "cf_id": 1572, "name": "Ximena Guy", "email": "xguy@protonmail.com"}',
#  156: '{"backer_id": "ab829", "cf_id": 563, "name": "Arnaud Becker", "email": "abecker@live.com"}',
#  157: '{"backer_id": "fd404", "cf_id": 65, "name": "Fiore Desautels", "email": "fdesautels@live.com"}',
#  158: '{"backer_id": "rm849", "cf_id": 563, "name": "Robby Mccray", "email": "rmccray@gmail.com"}',
#  159: '{"backer_id": "lr658", "cf_id": 65, "name": "Louis Rush", "email": "lrush@protonmail.com"}',
#  160: '{"backer_id": "sh994", "cf_id": 65, "name": "Serena Holzknecht", "email": "sholzknecht@protonmail.com"}',
#  161: '{"backer_id": "zv654", "cf_id": 65, "name": "Zan Verdier", "email": "zverdier@yahoo.com"}',
#  162: '{"backer_id": "hb861", "cf_id": 1572, "name": "Hipolito Baldocchi", "email": "hbaldocchi@gmail.com"}',
#  163: '{"backer_id": "hb280", "cf_id": 65, "name": "Hollis Barnett", "email": "hbarnett@live.com"}',
#  164: '{"backer_id": "be560", "cf_id": 65, "name": "Barend Edwards", "email": "bedwards@yandex.com"}',
#  165: '{"backer_id": "lh820", "cf_id": 563, "name": "Loane Holst", "email": "lholst@live.com"}',
#  166: '{"backer_id": "zp659", "cf_id": 1572, "name": "Zeno Pruneau", "email": "zpruneau@gmail.com"}',
#  167: '{"backer_id": "de758", "cf_id": 1114, "name": "Devon Epifano", "email": "depifano@protonmail.com"}',
#  168: '{"backer_id": "jb896", "cf_id": 65, "name": "Jarrett Barrera", "email": "jbarrera@gmail.com"}',
#  169: '{"backer_id": "wb355", "cf_id": 238, "name": "Walburg Burris", "email": "wburris@outlook.com"}',
#  170: '{"backer_id": "rd560", "cf_id": 65, "name": "Raffaela Darras", "email": "rdarras@gmail.com"}',
#  171: '{"backer_id": "er574", "cf_id": 1572, "name": "Eli Resta", "email": "eresta@outlook.com"}',
#  172: '{"backer_id": "jc163", "cf_id": 65, "name": "Jin Chen", "email": "jchen@outlook.com"}',
#  173: '{"backer_id": "kb942", "cf_id": 1114, "name": "Katja Butler", "email": "kbutler@protonmail.com"}',
#  174: '{"backer_id": "af969", "cf_id": 563, "name": "Allegra Fiedler", "email": "afiedler@yandex.com"}',
#  175: '{"backer_id": "bp212", "cf_id": 1572, "name": "Benton Pereira", "email": "bpereira@live.com"}',
#  176: '{"backer_id": "tc947", "cf_id": 65, "name": "Tesha Carpinello", "email": "tcarpinello@outlook.com"}',
#  177: '{"backer_id": "ak106", "cf_id": 1572, "name": "Anneli Kaufman", "email": "akaufman@outlook.com"}',
#  178: '{"backer_id": "mr294", "cf_id": 1572, "name": "Merle Rowe", "email": "mrowe@yahoo.com"}',
#  179: '{"backer_id": "bb365", "cf_id": 65, "name": "Bev Bellotti", "email": "bbellotti@yandex.com"}',
#  180: '{"backer_id": "bj274", "cf_id": 65, "name": "Blake Jenkins", "email": "bjenkins@outlook.com"}',
#  181: '{"backer_id": "qw345", "cf_id": 1572, "name": "Qiana Washington", "email": "qwashington@gmail.com"}',
#  182: '{"backer_id": "ra925", "cf_id": 65, "name": "Rayane Adam", "email": "radam@live.com"}',
#  183: '{"backer_id": "pg824", "cf_id": 968, "name": "Petronella Guilbaud", "email": "pguilbaud@outlook.com"}',
#  184: '{"backer_id": "ef414", "cf_id": 65, "name": "Elodia Forgione", "email": "eforgione@gmail.com"}',
#  185: '{"backer_id": "rp650", "cf_id": 238, "name": "Ryan Potts", "email": "rpotts@protonmail.com"}',
#  186: '{"backer_id": "se972", "cf_id": 1114, "name": "Sigmund Everett", "email": "severett@yahoo.com"}',
#  187: '{"backer_id": "sd958", "cf_id": 65, "name": "Serafina Desroches", "email": "sdesroches@yahoo.com"}',
#  188: '{"backer_id": "mb304", "cf_id": 65, "name": "Murray Barrese", "email": "mbarrese@yandex.com"}',
#  189: '{"backer_id": "lr409", "cf_id": 563, "name": "Luis Roberts", "email": "lroberts@protonmail.com"}',
#  190: '{"backer_id": "fm559", "cf_id": 65, "name": "Felicia Mcneil", "email": "fmcneil@outlook.com"}',
#  191: '{"backer_id": "wd714", "cf_id": 65, "name": "Willette Dattoli", "email": "wdattoli@outlook.com"}',
#  192: '{"backer_id": "ls638", "cf_id": 1572, "name": "Lucas Stephens", "email": "lstephens@protonmail.com"}',
#  193: '{"backer_id": "am362", "cf_id": 65, "name": "Amo Moses", "email": "amoses@outlook.com"}',
#  194: '{"backer_id": "ta190", "cf_id": 563, "name": "Tandy Acker", "email": "tacker@outlook.com"}',
#  195: '{"backer_id": "rb753", "cf_id": 65, "name": "Rolf Biron", "email": "rbiron@outlook.com"}',
#  196: '{"backer_id": "cc594", "cf_id": 65, "name": "Catharina Cappella", "email": "ccappella@gmail.com"}',
#  197: '{"backer_id": "vh915", "cf_id": 65, "name": "Virgilio Hyde", "email": "vhyde@live.com"}',
#  198: '{"backer_id": "og539", "cf_id": 65, "name": "Ollie Gwerder", "email": "ogwerder@yandex.com"}',
#  199: '{"backer_id": "dd470", "cf_id": 1911, "name": "Daniela Demers", "email": "ddemers@yahoo.com"}',
#  200: '{"backer_id": "ap718", "cf_id": 238, "name": "Angel Peragine", "email": "aperagine@live.com"}',
#  201: '{"backer_id": "vw158", "cf_id": 1572, "name": "Vicenzo Wells", "email": "vwells@yandex.com"}',
#  202: '{"backer_id": "fh696", "cf_id": 2284, "name": "Fernanda Hodges", "email": "fhodges@yandex.com"}',
#  203: '{"backer_id": "df617", "cf_id": 968, "name": "Darrin Fiedler", "email": "dfiedler@yahoo.com"}',
#  204: '{"backer_id": "jv716", "cf_id": 65, "name": "Janine Veronesi", "email": "jveronesi@gmail.com"}',
#  205: '{"backer_id": "tc807", "cf_id": 65, "name": "Terenzio Carver", "email": "tcarver@gmail.com"}',
#  206: '{"backer_id": "me460", "cf_id": 563, "name": "Magali Eilerts", "email": "meilerts@gmail.com"}',
#  207: '{"backer_id": "kp942", "cf_id": 1572, "name": "Kimber Puech", "email": "kpuech@protonmail.com"}',
#  208: '{"backer_id": "xp438", "cf_id": 563, "name": "Xenia Pergola", "email": "xpergola@yandex.com"}',
#  209: '{"backer_id": "af564", "cf_id": 1572, "name": "Arlena Fox", "email": "afox@protonmail.com"}',
#  210: '{"backer_id": "wn746", "cf_id": 1114, "name": "Wilfred Nazzaro", "email": "wnazzaro@yahoo.com"}',
#  211: '{"backer_id": "ad641", "cf_id": 1572, "name": "Angelina Decker", "email": "adecker@yahoo.com"}',
#  212: '{"backer_id": "rs660", "cf_id": 65, "name": "Ressie Schneider", "email": "rschneider@live.com"}',
#  213: '{"backer_id": "dp520", "cf_id": 65, "name": "Daine Pruneau", "email": "dpruneau@outlook.com"}',
#  214: '{"backer_id": "me520", "cf_id": 65, "name": "Marius Emilio", "email": "memilio@gmail.com"}',
#  215: '{"backer_id": "es977", "cf_id": 1572, "name": "Emily Stout", "email": "estout@gmail.com"}',
#  216: '{"backer_id": "sd883", "cf_id": 3138, "name": "Shaunna Dreher", "email": "sdreher@yahoo.com"}',
#  217: '{"backer_id": "tb283", "cf_id": 65, "name": "Toi Briere", "email": "tbriere@outlook.com"}',
#  218: '{"backer_id": "eb415", "cf_id": 65, "name": "Eliodoro Black", "email": "eblack@yahoo.com"}',
#  219: '{"backer_id": "fb116", "cf_id": 1572, "name": "Faustino Burgstaller", "email": "fburgstaller@outlook.com"}',
#  220: '{"backer_id": "jb391", "cf_id": 1572, "name": "Jeramy Benard", "email": "jbenard@yandex.com"}',
#  221: '{"backer_id": "ac624", "cf_id": 563, "name": "Annika Curtis", "email": "acurtis@live.com"}',
#  222: '{"backer_id": "kc104", "cf_id": 65, "name": "Kelia Campbell", "email": "kcampbell@protonmail.com"}',
#  223: '{"backer_id": "dg582", "cf_id": 65, "name": "Dario Gerst", "email": "dgerst@protonmail.com"}',
#  224: '{"backer_id": "mb933", "cf_id": 1572, "name": "Maryetta Bussa", "email": "mbussa@yahoo.com"}',
#  225: '{"backer_id": "em898", "cf_id": 65, "name": "Emerich Mccoy", "email": "emccoy@live.com"}',
#  226: '{"backer_id": "tw982", "cf_id": 968, "name": "Timothe Wilder", "email": "twilder@yandex.com"}',
#  227: '{"backer_id": "ab575", "cf_id": 65, "name": "Amadore Breitbarth", "email": "abreitbarth@protonmail.com"}',
#  228: '{"backer_id": "dg744", "cf_id": 1572, "name": "Dave Gaillard", "email": "dgaillard@live.com"}',
#  229: '{"backer_id": "cj442", "cf_id": 1572, "name": "Catrin Joseph", "email": "cjoseph@live.com"}',
#  230: '{"backer_id": "lo117", "cf_id": 65, "name": "Laverne Ortega", "email": "lortega@yandex.com"}',
#  231: '{"backer_id": "bg270", "cf_id": 65, "name": "Bulah Guay", "email": "bguay@yandex.com"}',
#  232: '{"backer_id": "jc692", "cf_id": 65, "name": "Jae Castellucci", "email": "jcastellucci@yahoo.com"}',
#  233: '{"backer_id": "jf750", "cf_id": 1572, "name": "Joseph Freeman", "email": "jfreeman@live.com"}',
#  234: '{"backer_id": "lr317", "cf_id": 968, "name": "Lena Robbins", "email": "lrobbins@live.com"}',
#  235: '{"backer_id": "cp253", "cf_id": 65, "name": "Charley Petitjean", "email": "cpetitjean@yandex.com"}',
#  236: '{"backer_id": "vv330", "cf_id": 65, "name": "Veronika Vesco", "email": "vvesco@live.com"}',
#  237: '{"backer_id": "ch724", "cf_id": 1572, "name": "Calandra Hofmeister", "email": "chofmeister@protonmail.com"}',
#  238: '{"backer_id": "dm121", "cf_id": 65, "name": "Devon Marques", "email": "dmarques@yandex.com"}',
#  239: '{"backer_id": "lc141", "cf_id": 65, "name": "Leon Carson", "email": "lcarson@gmail.com"}',
#  240: '{"backer_id": "am966", "cf_id": 65, "name": "Adelrico Meadows", "email": "ameadows@gmail.com"}',
#  241: '{"backer_id": "ab249", "cf_id": 65, "name": "Adel Becke", "email": "abecke@yahoo.com"}',
#  242: '{"backer_id": "mb828", "cf_id": 65, "name": "Mariya Babin", "email": "mbabin@outlook.com"}',
#  243: '{"backer_id": "pu317", "cf_id": 65, "name": "Peg Urciuoli", "email": "purciuoli@yandex.com"}',
#  244: '{"backer_id": "cb515", "cf_id": 1572, "name": "Clarita Barron", "email": "cbarron@protonmail.com"}',
#  245: '{"backer_id": "so203", "cf_id": 563, "name": "Silvia Olson", "email": "solson@gmail.com"}',
#  246: '{"backer_id": "aa284", "cf_id": 65, "name": "Armand Arnold", "email": "aarnold@live.com"}',
#  247: '{"backer_id": "sc143", "cf_id": 65, "name": "Sueann Casciani", "email": "scasciani@outlook.com"}',
#  248: '{"backer_id": "je217", "cf_id": 65, "name": "Jc Elliott", "email": "jelliott@yandex.com"}',
#  249: '{"backer_id": "ke511", "cf_id": 1114, "name": "Kalet Eaton", "email": "keaton@outlook.com"}',
#  250: '{"backer_id": "oa673", "cf_id": 563, "name": "Ottavia Abraham", "email": "oabraham@yandex.com"}',
#  251: '{"backer_id": "sc432", "cf_id": 968, "name": "Swanhild Cameron", "email": "scameron@yandex.com"}',
#  252: '{"backer_id": "aj655", "cf_id": 65, "name": "Alessandrina Jollenbeck", "email": "ajollenbeck@outlook.com"}',
#  253: '{"backer_id": "jp351", "cf_id": 968, "name": "Jamison Perona", "email": "jperona@live.com"}',
#  254: '{"backer_id": "lj758", "cf_id": 968, "name": "Louis Justice", "email": "ljustice@yahoo.com"}',
#  255: '{"backer_id": "ps794", "cf_id": 1572, "name": "Pablo Sykes", "email": "psykes@yandex.com"}',
#  256: '{"backer_id": "nb202", "cf_id": 1572, "name": "Nek Blecher", "email": "nblecher@yahoo.com"}',
#  257: '{"backer_id": "gp356", "cf_id": 968, "name": "Guadalupe Pannone", "email": "gpannone@outlook.com"}',
#  258: '{"backer_id": "rb945", "cf_id": 1572, "name": "Ramona Berg", "email": "rberg@yandex.com"}',
#  259: '{"backer_id": "gw991", "cf_id": 65, "name": "Gioconda Webster", "email": "gwebster@live.com"}',
#  260: '{"backer_id": "gb896", "cf_id": 910, "name": "George Bauers", "email": "gbauers@yahoo.com"}',
#  261: '{"backer_id": "jm345", "cf_id": 563, "name": "Julian Maillot", "email": "jmaillot@yandex.com"}',
#  262: '{"backer_id": "ma565", "cf_id": 1911, "name": "Melusina Asti", "email": "masti@yandex.com"}',
#  263: '{"backer_id": "oh728", "cf_id": 65, "name": "Ornella Hester", "email": "ohester@live.com"}',
#  264: '{"backer_id": "dg119", "cf_id": 1572, "name": "Dione Gass", "email": "dgass@yandex.com"}',
#  265: '{"backer_id": "kd744", "cf_id": 968, "name": "Konrad Damone", "email": "kdamone@yandex.com"}',
#  266: '{"backer_id": "ww138", "cf_id": 65, "name": "Walid Woods", "email": "wwoods@protonmail.com"}',
#  267: '{"backer_id": "gb135", "cf_id": 1572, "name": "Giana Blevins", "email": "gblevins@protonmail.com"}',
#  268: '{"backer_id": "lp541", "cf_id": 563, "name": "Lino Pires", "email": "lpires@yandex.com"}',
#  269: '{"backer_id": "hm752", "cf_id": 65, "name": "Helmina Mosco", "email": "hmosco@outlook.com"}',
#  270: '{"backer_id": "ib452", "cf_id": 1911, "name": "Inaya Barton", "email": "ibarton@yandex.com"}',
#  271: '{"backer_id": "fc303", "cf_id": 65, "name": "Francesca Chambers", "email": "fchambers@protonmail.com"}',
#  272: '{"backer_id": "kb141", "cf_id": 1114, "name": "Kenisha Bergfalk", "email": "kbergfalk@outlook.com"}',
#  273: '{"backer_id": "is909", "cf_id": 65, "name": "Ismael Sarrazin", "email": "isarrazin@live.com"}',
#  274: '{"backer_id": "hv133", "cf_id": 968, "name": "Holger Vitiello", "email": "hvitiello@protonmail.com"}',
#  275: '{"backer_id": "nm163", "cf_id": 65, "name": "Nayla Melendez", "email": "nmelendez@yahoo.com"}',
#  276: '{"backer_id": "cs899", "cf_id": 65, "name": "Camila Sciarretta", "email": "csciarretta@yandex.com"}',
#  277: '{"backer_id": "lh190", "cf_id": 65, "name": "Lucia Hatfield", "email": "lhatfield@gmail.com"}',
#  278: '{"backer_id": "as260", "cf_id": 65, "name": "Annetta Scholz", "email": "ascholz@live.com"}',
#  279: '{"backer_id": "db149", "cf_id": 65, "name": "Demarcus Barthelemy", "email": "dbarthelemy@gmail.com"}',
#  280: '{"backer_id": "cg952", "cf_id": 563, "name": "Clifton Garibaldi", "email": "cgaribaldi@live.com"}',
#  281: '{"backer_id": "tm490", "cf_id": 65, "name": "Tobias Mcintyre", "email": "tmcintyre@gmail.com"}',
#  282: '{"backer_id": "lt569", "cf_id": 65, "name": "Lalie Tyler", "email": "ltyler@outlook.com"}',
#  283: '{"backer_id": "ce212", "cf_id": 65, "name": "Cristiano Everhart", "email": "ceverhart@yandex.com"}',
#  284: '{"backer_id": "sr285", "cf_id": 2284, "name": "Shirl Rochon", "email": "srochon@live.com"}',
#  285: '{"backer_id": "tc231", "cf_id": 2882, "name": "Treena Ciampa", "email": "tciampa@yandex.com"}',
#  286: '{"backer_id": "ll471", "cf_id": 968, "name": "Luther Leonard", "email": "lleonard@gmail.com"}',
#  287: '{"backer_id": "aa130", "cf_id": 65, "name": "Affonso Abraham", "email": "aabraham@outlook.com"}',
#  288: '{"backer_id": "sb241", "cf_id": 563, "name": "So Boilard", "email": "sboilard@yandex.com"}',
#  289: '{"backer_id": "lb909", "cf_id": 968, "name": "Luther Barberi", "email": "lbarberi@yahoo.com"}',
#  290: '{"backer_id": "lw976", "cf_id": 910, "name": "Leuther Webb", "email": "lwebb@gmail.com"}',
#  291: '{"backer_id": "ab143", "cf_id": 1114, "name": "Abel Burke", "email": "aburke@outlook.com"}',
#  292: '{"backer_id": "cg893", "cf_id": 65, "name": "Calogero Geiger", "email": "cgeiger@outlook.com"}',
#  293: '{"backer_id": "nl492", "cf_id": 65, "name": "Nelson Lemire", "email": "nlemire@yahoo.com"}',
#  294: '{"backer_id": "nc285", "cf_id": 1572, "name": "Nadene Cartelli", "email": "ncartelli@live.com"}',
#  295: '{"backer_id": "ct703", "cf_id": 65, "name": "Calvin Tate", "email": "ctate@yandex.com"}',
#  296: '{"backer_id": "aw876", "cf_id": 1572, "name": "Axel Watts", "email": "awatts@protonmail.com"}',
#  297: '{"backer_id": "af506", "cf_id": 563, "name": "Alda Feigenbaum", "email": "afeigenbaum@live.com"}',
#  298: '{"backer_id": "es282", "cf_id": 65, "name": "Elena Shields", "email": "eshields@outlook.com"}',
#  299: '{"backer_id": "co633", "cf_id": 65, "name": "Circinus Odom", "email": "codom@yahoo.com"}',
#  300: '{"backer_id": "mh163", "cf_id": 65, "name": "Marietta Holzmann", "email": "mholzmann@yandex.com"}',
#  301: '{"backer_id": "pc978", "cf_id": 65, "name": "Peg Corriveau", "email": "pcorriveau@protonmail.com"}',
#  302: '{"backer_id": "gc386", "cf_id": 2882, "name": "Gregory Cianciolo", "email": "gcianciolo@live.com"}',
#  303: '{"backer_id": "nl252", "cf_id": 1114, "name": "Nolhan Lindsey", "email": "nlindsey@live.com"}',
#  304: '{"backer_id": "rb829", "cf_id": 1572, "name": "Romero Blau", "email": "rblau@gmail.com"}',
#  305: '{"backer_id": "gl884", "cf_id": 65, "name": "Genaro Larose", "email": "glarose@yahoo.com"}',
#  306: '{"backer_id": "og404", "cf_id": 65, "name": "Oralee Garbarino", "email": "ogarbarino@live.com"}',
#  307: '{"backer_id": "kr745", "cf_id": 1911, "name": "Karsten Riggs", "email": "kriggs@live.com"}',
#  308: '{"backer_id": "jc104", "cf_id": 238, "name": "Joris Cline", "email": "jcline@yandex.com"}',
#  309: '{"backer_id": "th958", "cf_id": 968, "name": "Tasha Holzknecht", "email": "tholzknecht@live.com"}',
#  310: '{"backer_id": "jb207", "cf_id": 65, "name": "Jarrett Beaumont", "email": "jbeaumont@yandex.com"}',
#  311: '{"backer_id": "lm386", "cf_id": 65, "name": "Laverne Maddalone", "email": "lmaddalone@yahoo.com"}',
#  312: '{"backer_id": "ic277", "cf_id": 968, "name": "Imre Carlson", "email": "icarlson@live.com"}',
#  313: '{"backer_id": "ab714", "cf_id": 968, "name": "Angel Brennan", "email": "abrennan@live.com"}',
#  314: '{"backer_id": "jm813", "cf_id": 2488, "name": "Jinny Michaud", "email": "jmichaud@live.com"}',
#  315: '{"backer_id": "ma226", "cf_id": 238, "name": "Maryam Armellino", "email": "marmellino@outlook.com"}',
#  316: '{"backer_id": "lm154", "cf_id": 1114, "name": "Lyle Massey", "email": "lmassey@yandex.com"}',
#  317: '{"backer_id": "pp209", "cf_id": 65, "name": "Peppe Pohl", "email": "ppohl@gmail.com"}',
#  318: '{"backer_id": "ss320", "cf_id": 1114, "name": "Shakita Sabatier", "email": "ssabatier@gmail.com"}',
#  319: '{"backer_id": "lb805", "cf_id": 1572, "name": "Lynwood Bozza", "email": "lbozza@yahoo.com"}',
#  320: '{"backer_id": "sf196", "cf_id": 968, "name": "Siglinde Flores", "email": "sflores@live.com"}',
#  321: '{"backer_id": "jc350", "cf_id": 1572, "name": "Jaden Castro", "email": "jcastro@outlook.com"}',
#  322: '{"backer_id": "bh958", "cf_id": 1114, "name": "Bartolo Haupt", "email": "bhaupt@outlook.com"}',
#  323: '{"backer_id": "vp800", "cf_id": 65, "name": "Venetta Perugini", "email": "vperugini@gmail.com"}',
#  324: '{"backer_id": "ec148", "cf_id": 1572, "name": "Ellsworth Clements", "email": "eclements@yahoo.com"}',
#  325: '{"backer_id": "ha431", "cf_id": 65, "name": "Harbin Alston", "email": "halston@outlook.com"}',
#  326: '{"backer_id": "sw972", "cf_id": 65, "name": "Syrine Walter", "email": "swalter@yahoo.com"}',
#  327: '{"backer_id": "sb891", "cf_id": 1572, "name": "Sansone Bisaillon", "email": "sbisaillon@protonmail.com"}',
#  328: '{"backer_id": "sf735", "cf_id": 1114, "name": "Shantay Fiori", "email": "sfiori@protonmail.com"}',
#  329: '{"backer_id": "mp538", "cf_id": 563, "name": "Mary Prince", "email": "mprince@protonmail.com"}',
#  330: '{"backer_id": "cf904", "cf_id": 1572, "name": "Catrin Ferguson", "email": "cferguson@gmail.com"}',
#  331: '{"backer_id": "gs818", "cf_id": 1572, "name": "Gianpiero Samson", "email": "gsamson@yandex.com"}',
#  332: '{"backer_id": "ra782", "cf_id": 1572, "name": "Robert Altieri", "email": "raltieri@protonmail.com"}',
#  333: '{"backer_id": "yc752", "cf_id": 1911, "name": "Yvone Capodanno", "email": "ycapodanno@live.com"}',
#  334: '{"backer_id": "le377", "cf_id": 563, "name": "Lucetta Eichel", "email": "leichel@protonmail.com"}',
#  335: '{"backer_id": "ja139", "cf_id": 968, "name": "Jalisa Anastasi", "email": "janastasi@yandex.com"}',
#  336: '{"backer_id": "jf881", "cf_id": 65, "name": "Jessi Farley", "email": "jfarley@yahoo.com"}',
#  337: '{"backer_id": "am638", "cf_id": 1114, "name": "Adolph Merrill", "email": "amerrill@gmail.com"}',
#  338: '{"backer_id": "rh663", "cf_id": 65, "name": "Riyad Holst", "email": "rholst@outlook.com"}',
#  339: '{"backer_id": "dl438", "cf_id": 238, "name": "Donatien Lefrancois", "email": "dlefrancois@yandex.com"}',
#  340: '{"backer_id": "je184", "cf_id": 1114, "name": "Jere Evans", "email": "jevans@outlook.com"}',
#  341: '{"backer_id": "xg938", "cf_id": 65, "name": "Xandi Glenn", "email": "xglenn@live.com"}',
#  342: '{"backer_id": "mg208", "cf_id": 563, "name": "Marianne Geiger", "email": "mgeiger@outlook.com"}',
#  343: '{"backer_id": "ag672", "cf_id": 65, "name": "Alonzo Gautier", "email": "agautier@protonmail.com"}',
#  344: '{"backer_id": "sc991", "cf_id": 65, "name": "Santo Cornacchia", "email": "scornacchia@yahoo.com"}',
#  345: '{"backer_id": "ar456", "cf_id": 238, "name": "Aleida Robertson", "email": "arobertson@yahoo.com"}',
#  346: '{"backer_id": "an122", "cf_id": 65, "name": "Alexandra Nolan", "email": "anolan@yandex.com"}',
#  347: '{"backer_id": "mh749", "cf_id": 65, "name": "Marina Habich", "email": "mhabich@protonmail.com"}',
#  348: '{"backer_id": "ac765", "cf_id": 65, "name": "Agnella Cloutier", "email": "acloutier@yahoo.com"}',
#  349: '{"backer_id": "ln560", "cf_id": 563, "name": "Loralee Nerone", "email": "lnerone@live.com"}',
#  350: '{"backer_id": "dm881", "cf_id": 1114, "name": "Dot Moore", "email": "dmoore@protonmail.com"}',
#  351: '{"backer_id": "wm699", "cf_id": 65, "name": "Wolf Morin", "email": "wmorin@gmail.com"}',
#  352: '{"backer_id": "ca628", "cf_id": 1114, "name": "Ciel Augustin", "email": "caugustin@yandex.com"}',
#  353: '{"backer_id": "ls538", "cf_id": 1114, "name": "Leontina Saucier", "email": "lsaucier@live.com"}',
#  354: '{"backer_id": "kr958", "cf_id": 563, "name": "Kathern Rodriquez", "email": "krodriquez@live.com"}',
#  355: '{"backer_id": "ad265", "cf_id": 65, "name": "Alder Dressler", "email": "adressler@outlook.com"}',
#  356: '{"backer_id": "am627", "cf_id": 1572, "name": "Aroghetto Manza", "email": "amanza@yahoo.com"}',
#  357: '{"backer_id": "rp666", "cf_id": 1572, "name": "Roberto Perry", "email": "rperry@gmail.com"}',
#  358: '{"backer_id": "rs221", "cf_id": 65, "name": "Reena Shaw", "email": "rshaw@protonmail.com"}',
#  359: '{"backer_id": "ma490", "cf_id": 65, "name": "Melina Abeln", "email": "mabeln@yandex.com"}',
#  360: '{"backer_id": "xd210", "cf_id": 65, "name": "Xavier Delahaye", "email": "xdelahaye@yahoo.com"}',
#  361: '{"backer_id": "mc413", "cf_id": 563, "name": "Moses Cece", "email": "mcece@protonmail.com"}',
#  362: '{"backer_id": "ss568", "cf_id": 1572, "name": "Sheilah Shaw", "email": "sshaw@yandex.com"}',
#  363: '{"backer_id": "dr174", "cf_id": 563, "name": "Daniela Rhodes", "email": "drhodes@gmail.com"}',
#  364: '{"backer_id": "vb927", "cf_id": 563, "name": "Viviana Belhumeur", "email": "vbelhumeur@protonmail.com"}',
#  365: '{"backer_id": "ms327", "cf_id": 65, "name": "Mireille Stanley", "email": "mstanley@protonmail.com"}',
#  366: '{"backer_id": "lf675", "cf_id": 1911, "name": "Lynetta Frank", "email": "lfrank@live.com"}',
#  367: '{"backer_id": "hb499", "cf_id": 65, "name": "Hermann Buckholtz", "email": "hbuckholtz@gmail.com"}',
#  368: '{"backer_id": "lb187", "cf_id": 65, "name": "Leane Boulanger", "email": "lboulanger@outlook.com"}',
#  369: '{"backer_id": "um200", "cf_id": 65, "name": "Ugo Mammone", "email": "umammone@yahoo.com"}',
#  370: '{"backer_id": "gh932", "cf_id": 65, "name": "Gail Hewitt", "email": "ghewitt@outlook.com"}',
#  371: '{"backer_id": "kl672", "cf_id": 65, "name": "Kermit Lowery", "email": "klowery@gmail.com"}',
#  372: '{"backer_id": "ab491", "cf_id": 563, "name": "Alois Behrend", "email": "abehrend@live.com"}',
#  373: '{"backer_id": "bb348", "cf_id": 1572, "name": "Bonito Bon", "email": "bbon@live.com"}',
#  374: '{"backer_id": "jv337", "cf_id": 2882, "name": "Jacinda Verde", "email": "jverde@yahoo.com"}',
#  375: '{"backer_id": "lh149", "cf_id": 65, "name": "Lloyd Holden", "email": "lholden@outlook.com"}',
#  376: '{"backer_id": "kw599", "cf_id": 3138, "name": "Kurigunde Wolfe", "email": "kwolfe@protonmail.com"}',
#  377: '{"backer_id": "mh683", "cf_id": 65, "name": "Marvin Hummel", "email": "mhummel@yahoo.com"}',
#  378: '{"backer_id": "bm342", "cf_id": 65, "name": "Baiardo Maglione", "email": "bmaglione@gmail.com"}',
#  379: '{"backer_id": "il539", "cf_id": 1114, "name": "Isaias Lyons", "email": "ilyons@yahoo.com"}',
#  380: '{"backer_id": "jl327", "cf_id": 563, "name": "Johnnie Le", "email": "jle@protonmail.com"}',
#  381: '{"backer_id": "wf249", "cf_id": 65, "name": "Walker Friedrich", "email": "wfriedrich@live.com"}',
#  382: '{"backer_id": "ba539", "cf_id": 1572, "name": "Benedict Allen", "email": "ballen@protonmail.com"}',
#  383: '{"backer_id": "sj553", "cf_id": 563, "name": "Sung Jordan", "email": "sjordan@gmail.com"}',
#  384: '{"backer_id": "gb371", "cf_id": 563, "name": "Garfield Bonnard", "email": "gbonnard@yahoo.com"}',
#  385: '{"backer_id": "hm715", "cf_id": 1572, "name": "Hansel Mecca", "email": "hmecca@outlook.com"}',
#  386: '{"backer_id": "ec905", "cf_id": 1114, "name": "Emy Chapman", "email": "echapman@gmail.com"}',
#  387: '{"backer_id": "lw634", "cf_id": 65, "name": "Lucetta Wilcox", "email": "lwilcox@outlook.com"}',
#  388: '{"backer_id": "dh507", "cf_id": 65, "name": "Danial Hummel", "email": "dhummel@yahoo.com"}',
#  389: '{"backer_id": "mr622", "cf_id": 65, "name": "Marion Ribeiro", "email": "mribeiro@gmail.com"}',
#  390: '{"backer_id": "gs461", "cf_id": 1572, "name": "Gilbert Spaziani", "email": "gspaziani@gmail.com"}',
#  391: '{"backer_id": "gb648", "cf_id": 563, "name": "Genevra Bentley", "email": "gbentley@gmail.com"}',
#  392: '{"backer_id": "eo125", "cf_id": 563, "name": "Emilio Owen", "email": "eowen@yahoo.com"}',
#  393: '{"backer_id": "rb185", "cf_id": 1572, "name": "Reid Borchard", "email": "rborchard@gmail.com"}',
#  394: '{"backer_id": "og865", "cf_id": 563, "name": "Oscar Gallant", "email": "ogallant@live.com"}',
#  395: '{"backer_id": "tr733", "cf_id": 563, "name": "Titouan Reginato", "email": "treginato@live.com"}',
#  396: '{"backer_id": "ac323", "cf_id": 65, "name": "Aniella Coleman", "email": "acoleman@yandex.com"}',
#  397: '{"backer_id": "lo326", "cf_id": 1911, "name": "Laurena Ortiz", "email": "lortiz@live.com"}',
#  398: '{"backer_id": "hc889", "cf_id": 563, "name": "Helaine Carignan", "email": "hcarignan@live.com"}',
#  399: '{"backer_id": "hv904", "cf_id": 65, "name": "Harold Vinci", "email": "hvinci@yandex.com"}',
#  400: '{"backer_id": "md370", "cf_id": 1114, "name": "Monte Dillon", "email": "mdillon@yandex.com"}',
#  401: '{"backer_id": "sb514", "cf_id": 1572, "name": "Shondra Bach", "email": "sbach@protonmail.com"}',
#  402: '{"backer_id": "sf324", "cf_id": 1572, "name": "Saul Fayolle", "email": "sfayolle@yahoo.com"}',
#  403: '{"backer_id": "eb537", "cf_id": 968, "name": "Etienne Buonopane", "email": "ebuonopane@live.com"}',
#  404: '{"backer_id": "bn189", "cf_id": 65, "name": "Beatrix Noble", "email": "bnoble@protonmail.com"}',
#  405: '{"backer_id": "sc931", "cf_id": 1114, "name": "Seema Cherry", "email": "scherry@protonmail.com"}',
#  406: '{"backer_id": "th234", "cf_id": 65, "name": "Toby Haupt", "email": "thaupt@gmail.com"}',
#  407: '{"backer_id": "lb460", "cf_id": 1114, "name": "Lamar Berger", "email": "lberger@yahoo.com"}',
#  408: '{"backer_id": "sp161", "cf_id": 563, "name": "Suzanne Paniccia", "email": "spaniccia@gmail.com"}',
#  409: '{"backer_id": "bm476", "cf_id": 238, "name": "Bianka Massey", "email": "bmassey@yandex.com"}',
#  410: '{"backer_id": "ta391", "cf_id": 563, "name": "Tomika Andrews", "email": "tandrews@protonmail.com"}',
#  411: '{"backer_id": "bm966", "cf_id": 1572, "name": "Bertha Maurin", "email": "bmaurin@protonmail.com"}',
#  412: '{"backer_id": "nm952", "cf_id": 1911, "name": "Nyla Mcconnell", "email": "nmcconnell@outlook.com"}',
#  413: '{"backer_id": "rg418", "cf_id": 65, "name": "Ronny Gotti", "email": "rgotti@gmail.com"}',
#  414: '{"backer_id": "rm381", "cf_id": 65, "name": "Rollin Magne", "email": "rmagne@yahoo.com"}',
#  415: '{"backer_id": "ab162", "cf_id": 65, "name": "Anae Buzzeo", "email": "abuzzeo@protonmail.com"}',
#  416: '{"backer_id": "gf246", "cf_id": 1114, "name": "Giada Fisher", "email": "gfisher@protonmail.com"}',
#  417: '{"backer_id": "ch750", "cf_id": 1114, "name": "Cletus Hatfield", "email": "chatfield@yandex.com"}',
#  418: '{"backer_id": "jg803", "cf_id": 1114, "name": "Jeffrey Gerber", "email": "jgerber@yahoo.com"}',
#  419: '{"backer_id": "pl955", "cf_id": 563, "name": "Philomena Leduc", "email": "pleduc@yandex.com"}',
#  420: '{"backer_id": "bc578", "cf_id": 968, "name": "Bellissa Carpenter", "email": "bcarpenter@yahoo.com"}',
#  421: '{"backer_id": "np469", "cf_id": 65, "name": "Nadene Pittman", "email": "npittman@yahoo.com"}',
#  422: '{"backer_id": "nj734", "cf_id": 65, "name": "Nakita Jourdain", "email": "njourdain@live.com"}',
#  423: '{"backer_id": "as672", "cf_id": 1114, "name": "Alger Spatafore", "email": "aspatafore@yahoo.com"}',
#  424: '{"backer_id": "lg912", "cf_id": 65, "name": "Luna Gallegos", "email": "lgallegos@live.com"}',
#  425: '{"backer_id": "rm719", "cf_id": 1114, "name": "Rosanna Mcbride", "email": "rmcbride@yahoo.com"}',
#  426: '{"backer_id": "kh931", "cf_id": 1114, "name": "Kali Haber", "email": "khaber@outlook.com"}',
#  427: '{"backer_id": "ml523", "cf_id": 65, "name": "Medwin Lazzaro", "email": "mlazzaro@live.com"}',
#  428: '{"backer_id": "df670", "cf_id": 1114, "name": "Dany Floyd", "email": "dfloyd@gmail.com"}',
#  429: '{"backer_id": "cs996", "cf_id": 968, "name": "Cristiana Stafford", "email": "cstafford@yahoo.com"}',
#  430: '{"backer_id": "wh607", "cf_id": 238, "name": "Warner Hermann", "email": "whermann@protonmail.com"}',
#  431: '{"backer_id": "jp523", "cf_id": 65, "name": "Javier Pearson", "email": "jpearson@yahoo.com"}',
#  432: '{"backer_id": "rw116", "cf_id": 563, "name": "Romano Whitehead", "email": "rwhitehead@protonmail.com"}',
#  433: '{"backer_id": "md744", "cf_id": 65, "name": "Marquis Dietrich", "email": "mdietrich@protonmail.com"}',
#  434: '{"backer_id": "df975", "cf_id": 65, "name": "Donovan Filiatrault", "email": "dfiliatrault@yandex.com"}',
#  435: '{"backer_id": "rl203", "cf_id": 563, "name": "Robert Lopardo", "email": "rlopardo@live.com"}',
#  436: '{"backer_id": "ab776", "cf_id": 65, "name": "Anael Beck", "email": "abeck@live.com"}',
#  437: '{"backer_id": "th710", "cf_id": 1572, "name": "Teofila Horn", "email": "thorn@protonmail.com"}',
#  438: '{"backer_id": "if257", "cf_id": 1572, "name": "Ishild Fusillo", "email": "ifusillo@outlook.com"}',
#  439: '{"backer_id": "ls716", "cf_id": 968, "name": "Lilas Suarez", "email": "lsuarez@yandex.com"}',
#  440: '{"backer_id": "bh265", "cf_id": 65, "name": "Beatrice Huffman", "email": "bhuffman@protonmail.com"}',
#  441: '{"backer_id": "bb194", "cf_id": 968, "name": "Bart Buhr", "email": "bbuhr@yahoo.com"}',
#  442: '{"backer_id": "sa754", "cf_id": 65, "name": "Sylvester Arnould", "email": "sarnould@gmail.com"}',
#  443: '{"backer_id": "jb318", "cf_id": 563, "name": "Joseph Berardinelli", "email": "jberardinelli@protonmail.com"}',
#  444: '{"backer_id": "ls852", "cf_id": 65, "name": "Lucca Stafford", "email": "lstafford@yandex.com"}',
#  445: '{"backer_id": "mf855", "cf_id": 968, "name": "Malvina Faerber", "email": "mfaerber@gmail.com"}',
#  446: '{"backer_id": "sg584", "cf_id": 1572, "name": "Sydney Guillard", "email": "sguillard@gmail.com"}',
#  447: '{"backer_id": "jg665", "cf_id": 238, "name": "Julie Garavaglia", "email": "jgaravaglia@yandex.com"}',
#  448: '{"backer_id": "ra144", "cf_id": 948, "name": "Raeann Atkins", "email": "ratkins@protonmail.com"}',
#  449: '{"backer_id": "ad490", "cf_id": 1572, "name": "Azucena Dresdner", "email": "adresdner@yandex.com"}',
#  450: '{"backer_id": "ab679", "cf_id": 65, "name": "Aminata Bonato", "email": "abonato@protonmail.com"}',
#  451: '{"backer_id": "mm395", "cf_id": 1572, "name": "Mariya Mays", "email": "mmays@gmail.com"}',
#  452: '{"backer_id": "tp337", "cf_id": 968, "name": "Trevor Prince", "email": "tprince@yahoo.com"}',
#  453: '{"backer_id": "li108", "cf_id": 563, "name": "Lamont Ingersleben", "email": "lingersleben@yandex.com"}',
#  454: '{"backer_id": "mb156", "cf_id": 65, "name": "Mirco Boisson", "email": "mboisson@protonmail.com"}',
#  455: '{"backer_id": "jc698", "cf_id": 1572, "name": "Jessica Camilli", "email": "jcamilli@protonmail.com"}',
#  456: '{"backer_id": "rm314", "cf_id": 65, "name": "Rodrigo Meadows", "email": "rmeadows@live.com"}',
#  457: '{"backer_id": "bm559", "cf_id": 563, "name": "Barrett Mcclain", "email": "bmcclain@yahoo.com"}',
#  458: '{"backer_id": "rj697", "cf_id": 1572, "name": "Rainer Jourdain", "email": "rjourdain@yahoo.com"}',
#  459: '{"backer_id": "eu931", "cf_id": 563, "name": "Edda Underwood", "email": "eunderwood@live.com"}',
#  460: '{"backer_id": "tf166", "cf_id": 65, "name": "Tad Fleming", "email": "tfleming@yandex.com"}',
#  461: '{"backer_id": "lb900", "cf_id": 65, "name": "Lindsey Beck", "email": "lbeck@live.com"}',
#  462: '{"backer_id": "kp905", "cf_id": 1572, "name": "Kirsten Poisson", "email": "kpoisson@yahoo.com"}',
#  463: '{"backer_id": "bm614", "cf_id": 65, "name": "Barney Morris", "email": "bmorris@protonmail.com"}',
#  464: '{"backer_id": "km622", "cf_id": 65, "name": "Kasi Merritt", "email": "kmerritt@live.com"}',
#  465: '{"backer_id": "bw202", "cf_id": 1572, "name": "Brunhilde Walter", "email": "bwalter@gmail.com"}',
#  466: '{"backer_id": "lb585", "cf_id": 1572, "name": "Lilly Billet", "email": "lbillet@gmail.com"}',
#  467: '{"backer_id": "ah247", "cf_id": 1572, "name": "Alfonzo Harris", "email": "aharris@yahoo.com"}',
# ...
#  846: '{"backer_id": "kp261", "cf_id": 65, "name": "Kathyrn Peck", "email": "kpeck@live.com"}',
#  847: '{"backer_id": "hb804", "cf_id": 65, "name": "Hilda Blumstein", "email": "hblumstein@protonmail.com"}',
#  848: '{"backer_id": "mb384", "cf_id": 968, "name": "Massima Baldocchi", "email": "mbaldocchi@protonmail.com"}',
#  849: '{"backer_id": "lp884", "cf_id": 1572, "name": "Lera Pearson", "email": "lpearson@protonmail.com"}',
#  850: '{"backer_id": "ae594", "cf_id": 65, "name": "Alleen Ellison", "email": "aellison@live.com"}',
#  851: '{"backer_id": "ta987", "cf_id": 1572, "name": "Tobias Althaus", "email": "talthaus@outlook.com"}',
#  852: '{"backer_id": "kd374", "cf_id": 65, "name": "Kim Desbiens", "email": "kdesbiens@yahoo.com"}',
#  853: '{"backer_id": "lt755", "cf_id": 65, "name": "Lucy Tringale", "email": "ltringale@gmail.com"}',
#  854: '{"backer_id": "ds585", "cf_id": 563, "name": "Dusti Sampson", "email": "dsampson@outlook.com"}',
#  855: '{"backer_id": "hm748", "cf_id": 238, "name": "Hyon Mcgowan", "email": "hmcgowan@outlook.com"}',
#  856: '{"backer_id": "bm320", "cf_id": 65, "name": "Benedikt Martin", "email": "bmartin@outlook.com"}',
#  857: '{"backer_id": "mm149", "cf_id": 65, "name": "Melina Montminy", "email": "mmontminy@yandex.com"}',
#  858: '{"backer_id": "nb639", "cf_id": 65, "name": "Nerezza Bottino", "email": "nbottino@yandex.com"}',
#  859: '{"backer_id": "cw520", "cf_id": 1572, "name": "Carter Washington", "email": "cwashington@yahoo.com"}',
#  860: '{"backer_id": "lb450", "cf_id": 65, "name": "Lashawnda Bradshaw", "email": "lbradshaw@yandex.com"}',
#  861: '{"backer_id": "ap187", "cf_id": 1114, "name": "Aldo Pohl", "email": "apohl@yandex.com"}',
#  862: '{"backer_id": "gt421", "cf_id": 968, "name": "Gaston Terrier", "email": "gterrier@protonmail.com"}',
#  863: '{"backer_id": "ep895", "cf_id": 968, "name": "Enric Pittman", "email": "epittman@live.com"}',
#  864: '{"backer_id": "wa701", "cf_id": 1572, "name": "Wonda Ayers", "email": "wayers@yahoo.com"}',
#  865: '{"backer_id": "yf490", "cf_id": 1114, "name": "Yasuko Fabel", "email": "yfabel@yandex.com"}',
#  866: '{"backer_id": "fl110", "cf_id": 65, "name": "Fredrik Lacroix", "email": "flacroix@live.com"}',
#  867: '{"backer_id": "lb870", "cf_id": 1114, "name": "Lucia Borgo", "email": "lborgo@protonmail.com"}',
#  868: '{"backer_id": "dg363", "cf_id": 65, "name": "Donatello Gordon", "email": "dgordon@protonmail.com"}',
#  869: '{"backer_id": "kb110", "cf_id": 1572, "name": "Kraig Busch", "email": "kbusch@live.com"}',
#  870: '{"backer_id": "fb424", "cf_id": 65, "name": "Fiona Brando", "email": "fbrando@protonmail.com"}',
#  871: '{"backer_id": "lw574", "cf_id": 65, "name": "Lisle Weaver", "email": "lweaver@live.com"}',
#  872: '{"backer_id": "ae918", "cf_id": 1114, "name": "Alec Ebner", "email": "aebner@yahoo.com"}',
#  873: '{"backer_id": "ar961", "cf_id": 968, "name": "Andreas Rigal", "email": "arigal@yahoo.com"}',
#  874: '{"backer_id": "mt716", "cf_id": 563, "name": "Malone Trani", "email": "mtrani@gmail.com"}',
#  875: '{"backer_id": "dk254", "cf_id": 968, "name": "Daniela Kirkland", "email": "dkirkland@outlook.com"}',
#  876: '{"backer_id": "am874", "cf_id": 65, "name": "Avril Mcintosh", "email": "amcintosh@protonmail.com"}',
#  877: '{"backer_id": "cr525", "cf_id": 948, "name": "Clotilde Rodrigue", "email": "crodrigue@live.com"}',
#  878: '{"backer_id": "wc513", "cf_id": 65, "name": "Wernher Carboni", "email": "wcarboni@yandex.com"}',
#  879: '{"backer_id": "bc364", "cf_id": 563, "name": "Bruna Clements", "email": "bclements@outlook.com"}',
#  880: '{"backer_id": "cf230", "cf_id": 65, "name": "Cody Feldt", "email": "cfeldt@yandex.com"}',
#  881: '{"backer_id": "jn670", "cf_id": 563, "name": "Junita Neveu", "email": "jneveu@outlook.com"}',
#  882: '{"backer_id": "bg581", "cf_id": 65, "name": "Barbara Gagliano", "email": "bgagliano@live.com"}',
#  883: '{"backer_id": "sh228", "cf_id": 1114, "name": "Sherice Hellewege", "email": "shellewege@yahoo.com"}',
#  884: '{"backer_id": "mj954", "cf_id": 65, "name": "Mitch Jalbert", "email": "mjalbert@live.com"}',
#  885: '{"backer_id": "jm101", "cf_id": 65, "name": "Johannes Magistro", "email": "jmagistro@yandex.com"}',
#  886: '{"backer_id": "nf369", "cf_id": 910, "name": "Nolann Foreman", "email": "nforeman@gmail.com"}',
#  887: '{"backer_id": "cg631", "cf_id": 65, "name": "Carline Goebel", "email": "cgoebel@yandex.com"}',
#  888: '{"backer_id": "lp218", "cf_id": 65, "name": "Livia Phaneuf", "email": "lphaneuf@outlook.com"}',
#  889: '{"backer_id": "of784", "cf_id": 65, "name": "Ottomar Foto", "email": "ofoto@yandex.com"}',
#  890: '{"backer_id": "ds610", "cf_id": 65, "name": "Deangela Schmidt", "email": "dschmidt@gmail.com"}',
#  891: '{"backer_id": "bb467", "cf_id": 1572, "name": "Bryant Borchard", "email": "bborchard@yahoo.com"}',
#  892: '{"backer_id": "bv607", "cf_id": 1114, "name": "Beatrix Vietti", "email": "bvietti@gmail.com"}',
#  893: '{"backer_id": "cp794", "cf_id": 968, "name": "Chaima Porter", "email": "cporter@gmail.com"}',
#  894: '{"backer_id": "aw326", "cf_id": 65, "name": "Armani Wheeler", "email": "awheeler@yahoo.com"}',
#  895: '{"backer_id": "ms559", "cf_id": 65, "name": "Min Schmidt", "email": "mschmidt@yandex.com"}',
#  896: '{"backer_id": "rl122", "cf_id": 563, "name": "Randal Lacasse", "email": "rlacasse@yahoo.com"}',
#  897: '{"backer_id": "mc544", "cf_id": 65, "name": "Maya Cira", "email": "mcira@yandex.com"}',
#  898: '{"backer_id": "mv762", "cf_id": 1114, "name": "Milan Valencia", "email": "mvalencia@outlook.com"}',
#  899: '{"backer_id": "rg638", "cf_id": 1114, "name": "Rosa Glover", "email": "rglover@yandex.com"}',
#  900: '{"backer_id": "eb865", "cf_id": 1114, "name": "Erich Braun", "email": "ebraun@yandex.com"}',
#  901: '{"backer_id": "eb701", "cf_id": 948, "name": "Eusebio Barthelemy", "email": "ebarthelemy@outlook.com"}',
#  902: '{"backer_id": "lb178", "cf_id": 238, "name": "Lara Buonopane", "email": "lbuonopane@outlook.com"}',
#  903: '{"backer_id": "aa484", "cf_id": 65, "name": "Anonciada Aguilar", "email": "aaguilar@yandex.com"}',
#  904: '{"backer_id": "sh493", "cf_id": 1114, "name": "Soraya Hudson", "email": "shudson@gmail.com"}',
#  905: '{"backer_id": "rg624", "cf_id": 65, "name": "Renda Gorman", "email": "rgorman@outlook.com"}',
#  906: '{"backer_id": "am644", "cf_id": 65, "name": "Anton Munier", "email": "amunier@yandex.com"}',
#  907: '{"backer_id": "ka406", "cf_id": 1572, "name": "Kiara Angelillo", "email": "kangelillo@protonmail.com"}',
#  908: '{"backer_id": "lb213", "cf_id": 65, "name": "Lucilla Black", "email": "lblack@outlook.com"}',
#  909: '{"backer_id": "wh558", "cf_id": 65, "name": "Willian Hoover", "email": "whoover@yahoo.com"}',
#  910: '{"backer_id": "jo527", "cf_id": 1572, "name": "Jenine Otto", "email": "jotto@live.com"}',
#  911: '{"backer_id": "hd242", "cf_id": 65, "name": "Helga Dupre", "email": "hdupre@live.com"}',
#  912: '{"backer_id": "dc144", "cf_id": 1114, "name": "Dorotea Cox", "email": "dcox@outlook.com"}',
#  913: '{"backer_id": "gh229", "cf_id": 968, "name": "Gonzalo Hansen", "email": "ghansen@outlook.com"}',
#  914: '{"backer_id": "ra187", "cf_id": 1572, "name": "Randell Abt", "email": "rabt@outlook.com"}',
#  915: '{"backer_id": "lg556", "cf_id": 563, "name": "Leni Grimard", "email": "lgrimard@gmail.com"}',
#  916: '{"backer_id": "fh102", "cf_id": 65, "name": "Fiammetta Huber", "email": "fhuber@outlook.com"}',
#  917: '{"backer_id": "lh128", "cf_id": 968, "name": "Larae Hildebrand", "email": "lhildebrand@outlook.com"}',
#  918: '{"backer_id": "ah861", "cf_id": 968, "name": "Annita Herve", "email": "aherve@yandex.com"}',
#  919: '{"backer_id": "ht719", "cf_id": 968, "name": "Holger Tangredi", "email": "htangredi@yandex.com"}',
#  920: '{"backer_id": "ll609", "cf_id": 1572, "name": "Lionel Langley", "email": "llangley@yandex.com"}',
#  921: '{"backer_id": "vr608", "cf_id": 65, "name": "Venezio Ramos", "email": "vramos@yandex.com"}',
#  922: '{"backer_id": "dd769", "cf_id": 1911, "name": "Desmond Dreschner", "email": "ddreschner@protonmail.com"}',
#  923: '{"backer_id": "cv209", "cf_id": 1572, "name": "Casey Villard", "email": "cvillard@yandex.com"}',
#  924: '{"backer_id": "fm638", "cf_id": 1114, "name": "Felizitas Morano", "email": "fmorano@yahoo.com"}',
#  925: '{"backer_id": "aj578", "cf_id": 65, "name": "Albane Jarvis", "email": "ajarvis@protonmail.com"}',
#  926: '{"backer_id": "ps285", "cf_id": 65, "name": "Paulita Salas", "email": "psalas@outlook.com"}',
#  927: '{"backer_id": "db210", "cf_id": 65, "name": "Delbert Baffa", "email": "dbaffa@outlook.com"}',
#  928: '{"backer_id": "au377", "cf_id": 2882, "name": "Amy Underwood", "email": "aunderwood@yandex.com"}',
#  929: '{"backer_id": "cg265", "cf_id": 1572, "name": "Cristiana Griffith", "email": "cgriffith@gmail.com"}',
#  930: '{"backer_id": "ds180", "cf_id": 968, "name": "Doyle Schmid", "email": "dschmid@live.com"}',
#  931: '{"backer_id": "rt281", "cf_id": 1114, "name": "Reita Tomasso", "email": "rtomasso@yahoo.com"}',
#  932: '{"backer_id": "ph749", "cf_id": 1572, "name": "Patrizia Hinton", "email": "phinton@live.com"}',
#  933: '{"backer_id": "tc503", "cf_id": 968, "name": "Tatiana Castillo", "email": "tcastillo@yahoo.com"}',
#  934: '{"backer_id": "mb313", "cf_id": 1572, "name": "Montrel Beckert", "email": "mbeckert@yandex.com"}',
#  935: '{"backer_id": "sl362", "cf_id": 563, "name": "Shawanda Lindsey", "email": "slindsey@gmail.com"}',
#  936: '{"backer_id": "uh381", "cf_id": 968, "name": "Ulbrecht Holland", "email": "uholland@live.com"}',
#  937: '{"backer_id": "km314", "cf_id": 65, "name": "Kara Marchitelli", "email": "kmarchitelli@yandex.com"}',
#  938: '{"backer_id": "eb969", "cf_id": 1114, "name": "Else Beck", "email": "ebeck@protonmail.com"}',
#  939: '{"backer_id": "tb251", "cf_id": 1572, "name": "Tod Byrd", "email": "tbyrd@protonmail.com"}',
#  940: '{"backer_id": "ld647", "cf_id": 65, "name": "Liselotte Dittmar", "email": "ldittmar@yandex.com"}',
#  941: '{"backer_id": "rl209", "cf_id": 65, "name": "Roque Lacoste", "email": "rlacoste@live.com"}',
#  942: '{"backer_id": "mt873", "cf_id": 65, "name": "Maynard Townsend", "email": "mtownsend@yahoo.com"}',
#  943: '{"backer_id": "lf516", "cf_id": 1572, "name": "Lucie Frost", "email": "lfrost@yahoo.com"}',
#  944: '{"backer_id": "ta679", "cf_id": 65, "name": "Tristan Acker", "email": "tacker@gmail.com"}',
#  945: '{"backer_id": "sd882", "cf_id": 968, "name": "Santo Drolet", "email": "sdrolet@outlook.com"}',
#  946: '{"backer_id": "dp941", "cf_id": 968, "name": "Dewayne Pasqual", "email": "dpasqual@live.com"}',
#  947: '{"backer_id": "ms270", "cf_id": 65, "name": "Maximino Small", "email": "msmall@yahoo.com"}',
#  948: '{"backer_id": "jf193", "cf_id": 65, "name": "Jonathan Faerber", "email": "jfaerber@yahoo.com"}',
#  949: '{"backer_id": "db832", "cf_id": 65, "name": "Desmond Beauchamp", "email": "dbeauchamp@protonmail.com"}',
#  950: '{"backer_id": "lc293", "cf_id": 65, "name": "Laura Cassone", "email": "lcassone@yahoo.com"}',
#  951: '{"backer_id": "sc440", "cf_id": 563, "name": "Suzi Chen", "email": "schen@protonmail.com"}',
#  952: '{"backer_id": "na467", "cf_id": 1911, "name": "Norbert Avella", "email": "navella@yahoo.com"}',
#  953: '{"backer_id": "mp998", "cf_id": 65, "name": "Milo Porter", "email": "mporter@gmail.com"}',
#  954: '{"backer_id": "rw179", "cf_id": 1572, "name": "Rainieri Ware", "email": "rware@yahoo.com"}',
#  955: '{"backer_id": "rd613", "cf_id": 1572, "name": "Rudolph Dresdner", "email": "rdresdner@outlook.com"}',
#  956: '{"backer_id": "dc677", "cf_id": 65, "name": "Dierk Costanzo", "email": "dcostanzo@yahoo.com"}',
#  957: '{"backer_id": "km838", "cf_id": 563, "name": "Kayla Mueller", "email": "kmueller@live.com"}',
#  958: '{"backer_id": "ha922", "cf_id": 65, "name": "Heriberto Ahlers", "email": "hahlers@protonmail.com"}',
#  959: '{"backer_id": "ma291", "cf_id": 968, "name": "Marceline Albert", "email": "malbert@gmail.com"}',
#  960: '{"backer_id": "ls903", "cf_id": 1114, "name": "Loretto Salas", "email": "lsalas@yandex.com"}',
#  961: '{"backer_id": "dl984", "cf_id": 65, "name": "Delila Lawrence", "email": "dlawrence@gmail.com"}',
#  962: '{"backer_id": "fj308", "cf_id": 563, "name": "Federico Jager", "email": "fjager@live.com"}',
#  963: '{"backer_id": "pf542", "cf_id": 968, "name": "Peter Fauteux", "email": "pfauteux@yahoo.com"}',
#  964: '{"backer_id": "mc619", "cf_id": 1572, "name": "Marvin Calandra", "email": "mcalandra@yandex.com"}',
#  965: '{"backer_id": "lc435", "cf_id": 65, "name": "Lucca Crosby", "email": "lcrosby@gmail.com"}',
#  966: '{"backer_id": "kr813", "cf_id": 65, "name": "Keena Rollins", "email": "krollins@yandex.com"}',
#  967: '{"backer_id": "eb667", "cf_id": 65, "name": "Edmund Baumann", "email": "ebaumann@yandex.com"}',
#  968: '{"backer_id": "sc261", "cf_id": 65, "name": "Sara Charbonneau", "email": "scharbonneau@protonmail.com"}',
#  969: '{"backer_id": "ht501", "cf_id": 65, "name": "Hortense Tangredi", "email": "htangredi@protonmail.com"}',
#  970: '{"backer_id": "cf209", "cf_id": 1572, "name": "Constanza Frost", "email": "cfrost@yahoo.com"}',
#  971: '{"backer_id": "th306", "cf_id": 65, "name": "Tanna Henson", "email": "thenson@yandex.com"}',
#  972: '{"backer_id": "uf135", "cf_id": 1572, "name": "Ute Favreau", "email": "ufavreau@yahoo.com"}',
#  973: '{"backer_id": "tt696", "cf_id": 65, "name": "Timeo Troncone", "email": "ttroncone@live.com"}',
#  974: '{"backer_id": "mr372", "cf_id": 65, "name": "Montrel Ruiz", "email": "mruiz@protonmail.com"}',
#  975: '{"backer_id": "lb930", "cf_id": 65, "name": "Lashaunda Battle", "email": "lbattle@outlook.com"}',
#  976: '{"backer_id": "ap347", "cf_id": 65, "name": "Alger Provencher", "email": "aprovencher@yandex.com"}',
#  977: '{"backer_id": "tb394", "cf_id": 65, "name": "Teofilo Briggs", "email": "tbriggs@protonmail.com"}',
#  978: '{"backer_id": "rn232", "cf_id": 65, "name": "Rosia Newman", "email": "rnewman@protonmail.com"}',
#  979: '{"backer_id": "df983", "cf_id": 563, "name": "Dewitt Fleischer", "email": "dfleischer@protonmail.com"}',
#  980: '{"backer_id": "ld418", "cf_id": 563, "name": "Liselotte Desrochers", "email": "ldesrochers@outlook.com"}',
#  981: '{"backer_id": "yv730", "cf_id": 65, "name": "Yasmine Vitulli", "email": "yvitulli@gmail.com"}',
#  982: '{"backer_id": "ea712", "cf_id": 563, "name": "Edda Alexander", "email": "ealexander@outlook.com"}',
#  983: '{"backer_id": "ky770", "cf_id": 65, "name": "Kim Young", "email": "kyoung@yahoo.com"}',
#  984: '{"backer_id": "jc963", "cf_id": 1114, "name": "Joyce Cilento", "email": "jcilento@protonmail.com"}',
#  985: '{"backer_id": "la958", "cf_id": 65, "name": "Luca Arnold", "email": "larnold@outlook.com"}',
#  986: '{"backer_id": "yg885", "cf_id": 65, "name": "Yacine Gulla", "email": "ygulla@outlook.com"}',
#  987: '{"backer_id": "ah815", "cf_id": 65, "name": "Aemilio Hill", "email": "ahill@protonmail.com"}',
#  988: '{"backer_id": "cm949", "cf_id": 65, "name": "Carmelia Mayo", "email": "cmayo@yandex.com"}',
#  989: '{"backer_id": "dt412", "cf_id": 65, "name": "Dorothea Thompson", "email": "dthompson@live.com"}',
#  990: '{"backer_id": "zm103", "cf_id": 65, "name": "Zelie Moroni", "email": "zmoroni@outlook.com"}',
#  991: '{"backer_id": "yh430", "cf_id": 1114, "name": "Yuette Hines", "email": "yhines@protonmail.com"}',
#  992: '{"backer_id": "sb943", "cf_id": 65, "name": "Sergio Bambach", "email": "sbambach@outlook.com"}',
#  993: '{"backer_id": "ot297", "cf_id": 65, "name": "Otis Trottier", "email": "otrottier@outlook.com"}',
#  994: '{"backer_id": "en876", "cf_id": 968, "name": "Elnora Naclerio", "email": "enaclerio@live.com"}',
#  995: '{"backer_id": "lp640", "cf_id": 65, "name": "Lashell Pope", "email": "lpope@outlook.com"}',
#  996: '{"backer_id": "es903", "cf_id": 563, "name": "Emilie Schulze", "email": "eschulze@outlook.com"}',
#  997: '{"backer_id": "nr568", "cf_id": 968, "name": "Noel Rocher", "email": "nrocher@outlook.com"}',
#  998: '{"backer_id": "nb860", "cf_id": 1572, "name": "Nario Barretto", "email": "nbarretto@outlook.com"}',
#  999: '{"backer_id": "hb501", "cf_id": 65, "name": "Heidy Beasley", "email": "hbeasley@live.com"}',
#  ...}

# %%
# Iterate through the backers DataFrame and convert each row to a dictionary.
backers_dict = backers_df.to_dict()
    # Iterate through each dictionary (row) and get the values for each row using list comprehension.
backer_id = []
cf_id = []
name = []
email = []
for backer in backers_dict['backer_info']:

    # Append the list of values for each row to a list. 
    backer_id.append(json.loads(backers_dict['backer_info'][backer])['backer_id'])
    cf_id.append(json.loads(backers_dict['backer_info'][backer])['cf_id'])
    name.append(json.loads(backers_dict['backer_info'][backer])['name'])
    email.append(json.loads(backers_dict['backer_info'][backer])['email'])
    
# Print out the list of values for each row.
print(backer_id, cf_id, name, email)
# Out:
# ['av166', 'ha127', 'lg794', 'tb566', 'lh506', 'lh382', 'em444', 'at582', 'id772', 'lw275', 'ub509', 'ha915', 'bb881', 'mg332', 'kd700', 'as695', 'iv513', 'ab842', 're181', 'kn133', 'gj893', 'vp915', 'ja995', 'ga249', 'td403', 'tv463', 'mw606', 'hc648', 'ta379', 'tj583', 'tc559', 'ww629', 'jg155', 'jd328', 'ld239', 'cv918', 'kb145', 'dw578', 'ad511', 'db633', 'cr369', 'mr978', 'md167', 'jr877', 'om753', 'ng231', 'tl316', 'dl139', 'mw253', 'im424', 'mb131', 'nc240', 'ab318', 'af301', 'bl736', 'ar957', 'cb474', 'dv246', 'cj111', 'lh765', 'wh697', 'eb714', 'ec356', 'yh129', 'as494', 'lb146', 'cc470', 'mm239', 'dg360', 'rh399', 'hr430', 'ar829', 'sw301', 'rr355', 'zc515', 'gp101', 'bm741', 'jd148', 'mm632', 'ls884', 'sp364', 'hh963', 'sb272', 'et566', 'sd421', 'tg563', 'kc571', 'sd121', 'sk744', 'km642', 'fu320', 'ld180', 'ds377', 'bb692', 'wd557', 'jd905', 'dd770', 'cv698', 'cn307', 'eb198', 'am869', 'gr400', 'az657', 'kc598', 'lb588', 'rl866', 'jf340', 'tb384', 'dg290', 'rr518', 'sh779', 'lw525', 'sl474', 'dp154', 'id770', 'ek669', 'eb945', 'ag917', 'ac437', 'sf583', 'sa973', 'kc836', 'bt844', 'mf392', 'dh568', 'iv880', 'gl219', 'kb890', 'jf901', 'ja340', 'ar906', 'dc579', 'gg660', 'db112', 'ld487', 'bj475', 'mc838', 'he768', 'pm973', 'bf986', 'sb322', 'ps571', 'mb333', 'ab290', 'jm190', 'rg933', 'ik787', 'rl982', 'ac179', 'eg193', 'fl258', 'mb203', 'en399', 'mr756', 'sc271', 'xg684', 'ab829', 'fd404', 'rm849', 'lr658', 'sh994', 'zv654', 'hb861', 'hb280', 'be560', 'lh820', 'zp659', 'de758', 'jb896', 'wb355', 'rd560', 'er574', 'jc163', 'kb942', 'af969', 'bp212', 'tc947', 'ak106', 'mr294', 'bb365', 'bj274', 'qw345', 'ra925', 'pg824', 'ef414', 'rp650', 'se972', 'sd958', 'mb304', 'lr409', 'fm559', 'wd714', 'ls638', 'am362', 'ta190', 'rb753', 'cc594', 'vh915', 'og539', 'dd470', 'ap718', 'vw158', 'fh696', 'df617', 'jv716', 'tc807', 'me460', 'kp942', 'xp438', 'af564', 'wn746', 'ad641', 'rs660', 'dp520', 'me520', 'es977', 'sd883', 'tb283', 'eb415', 'fb116', 'jb391', 'ac624', 'kc104', 'dg582', 'mb933', 'em898', 'tw982', 'ab575', 'dg744', 'cj442', 'lo117', 'bg270', 'jc692', 'jf750', 'lr317', 'cp253', 'vv330', 'ch724', 'dm121', 'lc141', 'am966', 'ab249', 'mb828', 'pu317', 'cb515', 'so203', 'aa284', 'sc143', 'je217', 'ke511', 'oa673', 'sc432', 'aj655', 'jp351', 'lj758', 'ps794', 'nb202', 'gp356', 'rb945', 'gw991', 'gb896', 'jm345', 'ma565', 'oh728', 'dg119', 'kd744', 'ww138', 'gb135', 'lp541', 'hm752', 'ib452', 'fc303', 'kb141', 'is909', 'hv133', 'nm163', 'cs899', 'lh190', 'as260', 'db149', 'cg952', 'tm490', 'lt569', 'ce212', 'sr285', 'tc231', 'll471', 'aa130', 'sb241', 'lb909', 'lw976', 'ab143', 'cg893', 'nl492', 'nc285', 'ct703', 'aw876', 'af506', 'es282', 'co633', 'mh163', 'pc978', 'gc386', 'nl252', 'rb829', 'gl884', 'og404', 'kr745', 'jc104', 'th958', 'jb207', 'lm386', 'ic277', 'ab714', 'jm813', 'ma226', 'lm154', 'pp209', 'ss320', 'lb805', 'sf196', 'jc350', 'bh958', 'vp800', 'ec148', 'ha431', 'sw972', 'sb891', 'sf735', 'mp538', 'cf904', 'gs818', 'ra782', 'yc752', 'le377', 'ja139', 'jf881', 'am638', 'rh663', 'dl438', 'je184', 'xg938', 'mg208', 'ag672', 'sc991', 'ar456', 'an122', 'mh749', 'ac765', 'ln560', 'dm881', 'wm699', 'ca628', 'ls538', 'kr958', 'ad265', 'am627', 'rp666', 'rs221', 'ma490', 'xd210', 'mc413', 'ss568', 'dr174', 'vb927', 'ms327', 'lf675', 'hb499', 'lb187', 'um200', 'gh932', 'kl672', 'ab491', 'bb348', 'jv337', 'lh149', 'kw599', 'mh683', 'bm342', 'il539', 'jl327', 'wf249', 'ba539', 'sj553', 'gb371', 'hm715', 'ec905', 'lw634', 'dh507', 'mr622', 'gs461', 'gb648', 'eo125', 'rb185', 'og865', 'tr733', 'ac323', 'lo326', 'hc889', 'hv904', 'md370', 'sb514', 'sf324', 'eb537', 'bn189', 'sc931', 'th234', 'lb460', 'sp161', 'bm476', 'ta391', 'bm966', 'nm952', 'rg418', 'rm381', 'ab162', 'gf246', 'ch750', 'jg803', 'pl955', 'bc578', 'np469', 'nj734', 'as672', 'lg912', 'rm719', 'kh931', 'ml523', 'df670', 'cs996', 'wh607', 'jp523', 'rw116', 'md744', 'df975', 'rl203', 'ab776', 'th710', 'if257', 'ls716', 'bh265', 'bb194', 'sa754', 'jb318', 'ls ...

# %%
# Create a backers_df DataFrame with the following columns:
# 'backer_id','cf_id', 'name', and 'email' 
# using the list of values lists. 
d = {'backer_id' : backer_id,'cf_id' : cf_id, 'name' : name, 'email' : email}
backers_df = pd.DataFrame(data=d)
backers_df.head()
# Out:
#   backer_id  cf_id              name                  email
# 0     av166    968    Angelo Vincent      avincent@live.com
# 1     ha127    563     Hubert Arnold     harnold@yandex.com
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com
# 4     lh506    563        Lexie Hunt         lhunt@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backers_df.to_csv("backers.csv", encoding='utf8', index=False)

# %% [markdown]
# ## Deliverable 2: Transform and Clean Data
# ----
# 1. Check the data types of the columns and convert the "cf_id" column to an integer, if necessary.
# 2. Split the name in the "name" column into first and last names, and add them to "first_name" and "last_name" columns in the DataFrame.
# 3. Drop the "name" column in the DataFrame.
# 4. Place the columns in the following order; "backer_id", "cf_id", "first_name", "last_name" and "email".

# %%
# Check data types.
backers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8175 entries, 0 to 8174
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   backer_id  8175 non-null   object
#  1   cf_id      8175 non-null   int64
#  2   name       8175 non-null   object
#  3   email      8175 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 255.6+ KB

# %%
# Split the "name" column into "first_name" and "last_name" columns.
#backers_df["name"].values.to_list()
backers_df[['first_name','last_name']] = backers_df["name"].str.split(expand=True)
#backers_df['first_name'] = backers_df['name'].split(" ")[0]
#backers_df['last_name'] = backers_df['name'].split(" ")[1]
backers_df.head()
# Out:
#   backer_id  cf_id              name                  email first_name  \
# 0     av166    968    Angelo Vincent      avincent@live.com     Angelo
# 1     ha127    563     Hubert Arnold     harnold@yandex.com     Hubert
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com      Loris
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com    Teodora
# 4     lh506    563        Lexie Hunt         lhunt@live.com      Lexie
#
#   last_name
# 0   Vincent
# 1    Arnold
# 2    Goulet
# 3  Brunelli
# 4      Hunt

# %%
#  Drop the name column
backers_df.drop(columns=["name"])

# Reorder the columns
column_order = ["backer_id", "cf_id", "first_name", "last_name", "email"]
backers_df = backers_df[column_order]
backers_df.head()
# Out:
#   backer_id  cf_id first_name last_name                  email
# 0     av166    968     Angelo   Vincent      avincent@live.com
# 1     ha127    563     Hubert    Arnold     harnold@yandex.com
# 2     lg794     65      Loris    Goulet     lgoulet@yandex.com
# 3     tb566    563    Teodora  Brunelli  tbrunelli@outlook.com
# 4     lh506    563      Lexie      Hunt         lhunt@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backers_df.to_csv("backers.csv", encoding='utf8', index=False)
